# %% [markdown]
# # Clython

# %% [markdown]
# ## Version 0.2.0
# [Подробнее]()

# %% [markdown]
# # Подключение общего интерпритатора

# %%
from build_0_2_0.clython import main

# %% [markdown]
# ## Tests CLython

# %%
main(['all_tests'])
# Out:
# tests
# TESTS:
# ...

# %% [markdown]
# ## Go Tests

# %% [markdown]
# ### Множественное тестирование

# %%
main(['test'])
# Out:
# test
# Выполняется тест Input #0
# Входные данные: (print 1)
# Ожидаемые выходные данные: ['1']
# (print 1)
# parse_code: ['(', 'print', '1', ')']
# parse_code: ['(', 'print', '1', ')']
# command_doings: [{'function': 'print', 'type': '__magic__', 'args': ['1']}]
# command_doings: [{'function': 'print', 'type': '__magic__', 'args': ['1']}]
# command: {'function': 'print', 'type': '__magic__', 'args': ['1']}
# <class 'tuple'>
# (['1'],)
# print_args: 1
# 1
# output: ['1']
# Выполнение кода завершено!
# Выходные данные: ['1']
# Good: Тест Input #0 - прошёл!
# ----------------------------------------------------------------------------------------------------
# Выполняется тест Input #1
# Входные данные: (println 1)
# Ожидаемые выходные данные: ['1']
# (println 1)
# parse_code: ['(', 'println', '1', ')']
# parse_code: ['(', 'println', '1', ')']
# command_doings: [{'function': 'println', 'type': '__magic__', 'args': ['1']}]
# ...
